# %%
import numpy as np
import pandas as pd
import scipy as sp
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.metrics import roc_auc_score, f1_score

import xgboost as xgb

# %%
def diff_time(a,b):
    a_day, a_hour, a_minute, a_second = (a / 1000000, a / 10000 % 100, a / 100 % 100, a % 100)
    b_day, b_hour, b_minute, b_second = (b / 1000000, b / 10000 % 100, b / 100 % 100, b % 100)
    
    d_day = b_day - a_day
    d_hour = b_hour - a_hour
    d_minute = b_minute - a_minute
    d_second = b_second - a_second
    
    diff = d_day * 24 * 60 * 60 + d_hour * 60 * 60 + d_minute * 60 + d_second
    return diff

def get_diff_time(x):
    diff_t = []
    for d in x:
#         print d
        diff_t.append(diff_time(d[0],d[1]))
    return diff_t

# %%
def get_data(add_data=False):
    df_train_voice_feat = pd.read_csv('../xdata/df_train_voice_feat.csv')
    df_test_voice_feat = pd.read_csv('../xdata/df_testB_voice_feat.csv')
    if add_data==True:
        df_trainA = pd.read_csv('../xdata/df_testA_label.csv')
        df_trainA_voice_feat = pd.read_csv('../xdata/df_testA_voice_feat.csv')
        
    
    df_train_sms_feat = pd.read_csv('../xdata/df_train_sms_feat.csv')
    df_test_sms_feat = pd.read_csv('../xdata/df_testB_sms_feat.csv')
    if add_data==True:
        df_trainA_sms_feat = pd.read_csv('../xdata/df_testA_sms_feat.csv')
    
    df_train_sms_feat.drop('label',axis=1,inplace=True)
    
    df_train_wa_feat = pd.read_csv('../xdata/df_train_wa_feat.csv')
    df_test_wa_feat = pd.read_csv('../xdata/df_testB_wa_feat.csv')
    if add_data==True:
        df_trainA_wa_feat = pd.read_csv('../xdata/df_testA_wa_feat.csv')
    df_train_wa_feat.drop('label',axis=1,inplace=True)
    
#     df_train_voice_sms_feat = pd.read_csv('../xdata/df_train_voice_sms_feat.csv')
#     df_test_voice_sms_feat = pd.read_csv('../xdata/df_testB_voice_sms_feat.csv')
#     df_train_voice_sms_feat.drop('label',axis=1,inplace=True)
    
    
    df_train = pd.merge(df_train_voice_feat, df_train_sms_feat, on='uid', how='left')
    df_test = pd.merge(df_test_voice_feat, df_test_sms_feat, on='uid', how='left')
    
    df_train = pd.merge(df_train, df_train_wa_feat, on='uid', how='left')
    df_test = pd.merge(df_test, df_test_wa_feat, on='uid', how='left')
    
#     df_train = pd.merge(df_train, df_train_voice_sms_feat, on='uid', how='left')
#     df_test = pd.merge(df_test, df_test_voice_sms_feat, on='uid', how='left')
    
    
    if add_data==True:
        df_trainA = pd.merge(df_trainA, df_trainA_voice_feat, on='uid', how='left')
        df_trainA = pd.merge(df_trainA, df_trainA_sms_feat, on='uid', how='left')
        df_trainA = pd.merge(df_trainA, df_trainA_wa_feat, on='uid', how='left')
#         df_trainA = df_trainA[df_trainA['label']==1]
        df_trainA = df_trainA[:100]
        
        
        df_train = df_train.append(df_trainA)
    
        
    df_train.replace([np.inf,-np.inf], 0, inplace=True)
    df_test.replace([np.inf,-np.inf], 0, inplace=True)

    df_train.fillna(0,inplace=True)
    df_test.fillna(0,inplace=True)

    
    
    # 组合特征
    # voice_all_start_time_first
    # voice_all_start_time_last 
    # voice_all_end_time_first
    # voice_all_end_time_last
    
    # sms_all_start_time_last
    # sms_all_start_time_first
    for sms_time in ['sms_all_start_time_first', 'sms_all_start_time_last']:
        df_train[sms_time] = df_train[sms_time].astype(int)
        df_test[sms_time] = df_test[sms_time].astype(int)
        
        for voice_time in ['voice_all_start_time_first','voice_all_start_time_last','voice_all_end_time_first','voice_all_end_time_last']:
            df_train[voice_time] = df_train[voice_time].astype(int)
            df_test[voice_time] = df_test[voice_time].astype(int)
        
            df_train[sms_time+'_'+voice_time] = get_diff_time(df_train[[sms_time,voice_time]].values)
            df_test[sms_time+'_'+voice_time] = get_diff_time(df_test[[sms_time,voice_time]].values)
            
            # 除以对应的不同的次数，
            df_train[sms_time+'_'+voice_time+'_voice_rate'] = df_train[sms_time+'_'+voice_time] / df_train['voice_all_cnt']
            df_test[sms_time+'_'+voice_time+'_voice_rate'] = df_test[sms_time+'_'+voice_time] / df_test['voice_all_cnt']
    
            df_train[sms_time+'_'+voice_time+'_sms_rate'] = df_train[sms_time+'_'+voice_time] / df_train['sms_all_cnt']
            df_test[sms_time+'_'+voice_time+'_sms_rate'] = df_test[sms_time+'_'+voice_time] / df_test['sms_all_cnt']
    
    df_train['wa_all_wa_name_little_wite_risk'] = df_train['wa_all_wa_name_little_wite_risk'].astype(int)
    df_train['wa_all_wa_name_many_wite_risk'] = df_train['wa_all_wa_name_many_wite_risk'].astype(int)
    
    df_test['wa_all_wa_name_little_wite_risk'] = df_test['wa_all_wa_name_little_wite_risk'].astype(int)
    df_test['wa_all_wa_name_many_wite_risk'] = df_test['wa_all_wa_name_many_wite_risk'].astype(int)

    
    return df_train, df_test

    
    
def split_train_valid(df_train,test_size=0.2):
    '''
    k-fold交叉验证,默认k=10
    df_train:训练数据
    '''
    X_train, X_vali, y_train, y_vali = train_test_split(df_train[features], df_train[label], test_size=test_size, random_state=40000)
    #added some parameters
    
#     dtrain = df_train.iloc[train_list]
#     dvali =  df_train.iloc[vali_list]
    
    dtrain = xgb.DMatrix(X_train,label=y_train)
    dvalid = xgb.DMatrix(X_vali,label=y_vali)
    watchlist = [(dtrain, 'train'),(dvalid, 'valid')]
    
    return dtrain, dvalid, watchlist

# %%
# 设置特征数据，去除id数据，不能进行预测
df_train, df_test = get_data(add_data=True)

df_train.info()
df_test.info()

features = df_test.columns
features = list(features)
features.remove('uid')
features.remove('wa_all_wa_name_little_wite')
features.remove('wa_all_wa_name_many_wite')

label = 'label'

print len(features)

features_ = open('features.txt','r').readlines()
features_ = [feat.strip() for feat in features_]

# features = list(set(features) - set(features_))
print len(features)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5099 entries, 0 to 99
# Columns: 2065 entries, label to sms_all_start_time_last_voice_all_end_time_last_sms_rate
# dtypes: float64(2043), int64(19), object(3)
# memory usage: 80.4+ MB
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3000 entries, 0 to 2999
# Columns: 2064 entries, uid to sms_all_start_time_last_voice_all_end_time_last_sms_rate
# dtypes: float64(2043), int64(18), object(3)
# memory usage: 47.3+ MB
# 2061
# 2061

# %%
df_train['label'].value_counts()
# Out:
# 0    4099
# 1    1000
# Name: label, dtype: int64

# %% [markdown]
# ## 组合特征
# 1. 组合时间差值，组合比例计算，voice,sms,wa等三种情况

# %%
xgb17_first_step_models = []
rf7_first_step_models = []
gbdt_first_step_models = []
lr_model = None

def get_xgb17_first_step_model(df_train):
    '''
    stacking的第一层，使用17个不同的seed得到15维特征，返回15个模型
    
    '''
    seed = 71
    np.random.seed(seed)

    param = {'max_depth':3, # 基准是5 
         'eta':0.05,
         'gamma ':0.1,
         'colsample_bytree':0.8, # old 0.8
         'subsample':0.8,
         'silent':1,
         'eval_metric':'auc',
         'objective':'binary:logistic',
#          'scale_pos_weight':5,
         'seed': seed
        }

    nround = 150 # 参数求的
    models = []
    seeds = [71,73,91,101,2017,2018,2019,2020,10003,100007,100009,20003,200005,12345,123456]
    for i in range(len(seeds)):
        print('LOOP',i)
        dbuild, dvalid, watchlist = split_train_valid(df_train,test_size=0.002)
        param['seed'] = seeds[i]
        model = xgb.train(param, dbuild, nround, watchlist,verbose_eval=20)
        models.append(model)
        
        # VALID
#         valid_yhat = model.predict(dvalid,ntree_limit=model.best_iteration)
#         print('Valid Mean:---------------------->', np.mean(valid_yhat))
        del dbuild, dvalid, watchlist
    return models


def get_lr_first_step_model(df_train):
    '''
    得到3个lr model
    '''
    pass

# %%
seed = 71
np.random.seed(seed)
param = {'max_depth':3, # 基准是5,过拟合 
         'eta':0.05,
         'gamma ':0.1,
         'colsample_bytree':0.8, # old 0.8
         'subsample':0.8,
         'silent':1,
         'eval_metric':'auc',
         'objective':'binary:logistic',
#          'scale_pos_weight':5,
         'seed': seed
        }

ESR = 50
nround = 1000

# %%
LOOP = 3
models = []
seeds = [71,73,91]
for i in range(LOOP):
    print('LOOP',i)
#     dbuild, dvalid, watchlist = split_build_valid(df_train)
    dbuild, dvalid, watchlist = split_train_valid(df_train,test_size=0.2)
    param['seed'] = seeds[i]
    model = xgb.train(param, dbuild, nround, watchlist,early_stopping_rounds=ESR,verbose_eval=20)
    models.append(model)
#     model.save_model('./model1'+ str(i) + '.model')
    # VALID
    valid_yhat = model.predict(dvalid,ntree_limit=model.best_iteration)
    print('Valid Mean:---------------------->', np.mean(valid_yhat))
    del dbuild, dvalid, watchlist
# Out:
# ('LOOP', 0)
# [0]	train-auc:0.855825	valid-auc:0.806281
# Multiple eval metrics have been passed: 'valid-auc' will be used for early stopping.
#
# Will train until valid-auc hasn't improved in 50 rounds.
# [20]	train-auc:0.944514	valid-auc:0.901794
# [40]	train-auc:0.959609	valid-auc:0.915949
# [60]	train-auc:0.97087	valid-auc:0.921351
# [80]	train-auc:0.979391	valid-auc:0.923564
# [100]	train-auc:0.985777	valid-auc:0.923678
# [120]	train-auc:0.991162	valid-auc:0.922394
# Stopping. Best iteration:
# [88]	train-auc:0.98212	valid-auc:0.924505
#
# ('Valid Mean:---------------------->', 0.1892371)
# ('LOOP', 1)
# [0]	train-auc:0.854012	valid-auc:0.807433
# Multiple eval metrics have been passed: 'valid-auc' will be used for early stopping.
#
# Will train until valid-auc hasn't improved in 50 rounds.
# [20]	train-auc:0.944019	valid-auc:0.898056
# [40]	train-auc:0.959275	valid-auc:0.918065
# [60]	train-auc:0.970564	valid-auc:0.921858
# [80]	train-auc:0.979583	valid-auc:0.921954
# [100]	train-auc:0.986048	valid-auc:0.922551
# [120]	train-auc:0.990628	valid-auc:0.922069
# [140]	train-auc:0.994096	valid-auc:0.923009
# [160]	train-auc:0.996301	valid-auc:0.923063
# [180]	train-auc:0.997782	valid-auc:0.922955
# Stopping. Best iteration:
# [137]	train-auc:0.993809	valid-auc:0.923745
#
# ('Valid Mean:---------------------->', 0.18002726)
# ('LOOP', 2)
# [0]	train-auc:0.859811	valid-auc:0.812485
# Multiple eval metrics have been passed: 'valid-auc' will be used for early stopping.
#
# Will train until valid-auc hasn't improved in 50 rounds.
# [20]	train-auc:0.941008	valid-auc:0.897342
# [40]	train-auc:0.958265	valid-auc:0.918125
# [60]	train-auc:0.96951	valid-auc:0.922641
# [80]	train-auc:0.978242	valid-auc:0.924613
# [100]	train-auc:0.985453	valid-auc:0.926663
# [120]	train-auc:0.991197	valid-auc:0.928177
# [140]	train-auc:0.994393	valid-auc:0.929063
# [160]	train-auc:0.996708	valid-auc:0.929612
# [180]	train-auc:0.997877	valid-auc:0.928804
# [200]	train-auc:0.998839	valid-auc:0.928623
# Stopping. Best iteration:
# [154]	train-auc:0.996054	valid-auc:0.929883
#
# ('Valid Mean:---------------------->', 0.18041213)

# %%
dtest  = xgb.DMatrix(df_test[features])
proba_test = pd.DataFrame()
proba_test['uid'] = df_test['uid']
proba_test['score'] = [0 for i in range(len(df_test))]
for model in models:
    proba_test['score'] += model.predict(dtest)
proba_test['score'] /= LOOP

proba_test = proba_test.sort_values('score',ascending=False)
proba_test['label'] = [0 for i in range(len(proba_test))]

# %%
# proba_test[:500]

# %%
proba_test.loc[proba_test['score']>0.36, 'label'] = 1
proba_test[['uid','label']].to_csv('../result/xresultB_1.csv',index=False,header=False)

# %%
proba_test['label'].value_counts()
# Out:
# 0    2481
# 1     519
# Name: label, dtype: int64

# %%
# 计算特征重要程度
import operator
importance = model.get_fscore()
importance = sorted(importance.items(), key=operator.itemgetter(1),reverse=True)

print len(importance)
# Out:
# 906

# %%
# Out:
# ['voice_all_cnt',
#  'voice_all_unique_cnt',
#  'voice_all_per_opp_rate',
#  'voice_all_opp_head_unique_cnt',
#  'voice_all_opp_head_little_head',
#  'voice_all_opp_head_many_head',
#  'voice_all_opp_head_many_head_cnt',
#  'voice_all_opp_head_many_head_cnt_rate',
#  'voice_all_opp_head_many_head_cnt_rate_unique',
#  'voice_all_opp_len_3',
#  'voice_all_opp_len_5',
#  'voice_all_opp_len_6',
#  'voice_all_opp_len_7',
#  'voice_all_opp_len_8',
#  'voice_all_opp_len_9',
#  'voice_all_opp_len_10',
#  'voice_all_opp_len_11',
#  'voice_all_opp_len_12',
#  'voice_all_opp_len_13',
#  'voice_all_opp_len_14',
#  'voice_all_opp_len_15',
#  'voice_all_opp_len_16',
#  'voice_all_opp_len_17',
#  'voice_all_opp_len_19',
#  'voice_all_opp_len_20',
#  'voice_all_opp_len_11_rate',
#  'voice_all_opp_len_little_head',
#  'voice_all_opp_len_many_head',
#  'voice_all_call_type_1',
#  'voice_all_call_type_2',
#  'voice_all_call_type_3',
#  'voice_all_call_type_4',
#  'voice_all_call_type_1_rate',
#  'voice_all_call_type_2_rate',
#  'voice_all_call_type_3_rate',
#  'voice_all_call_type_4_rate',
#  'voice_all_in_out_0',
#  'voice_all_in_out_1',
#  'voice_all_in_out_0_rate',
#  'voice_all_in_out_1_rate',
#  'voice_all_start_end_time_day_1',
#  'voice_all_start_end_time_day_2',
#  'voice_all_start_end_time_day_3',
#  'voice_all_start_end_time_day_4',
#  'voice_all_start_end_time_day_5',
#  'voice_all_start_end_time_day_6',
#  'voice_all_start_end_time_day_7',
#  'voice_all_start_end_time_day_8',
#  'voice_all_start_end_time_day_9',
#  'voice_all_start_end_time_day_10',
#  'voice_all_start_end_time_day_11',
#  'voice_all_start_end_time_day_12',
#  'voice_all_start_end_time_day_13',
#  'voice_all_start_end_time_day_14',
#  'voice_all_start_end_time_day_15',
#  'voice_all_start_end_time_day_16',
#  'voice_all_start_end_time_day_17',
#  'voice_all_start_end_time_day_18',
#  'voice_all_start_end_time_day_19',
#  'voice_all_start_end_time_day_20',
#  'voice_all_start_end_time_day_21',
#  'voice_all_start_end_time_day_22',
#  'voice_all_start_end_time_day_23',
#  'voice_all_start_end_time_day_24',
#  'voice_all_start_end_time_day_25',
#  'voice_all_start_end_time_day_26',
#  'voice_all_start_end_time_day_27',
#  'voice_all_start_end_time_day_28',
#  'voice_all_start_end_time_day_29',
#  'voice_all_start_end_time_day_30',
#  'voice_all_start_end_time_day_31',
#  'voice_all_start_end_time_day_32',
#  'voice_all_start_end_time_day_33',
#  'voice_all_start_end_time_day_34',
#  'voice_all_start_end_time_day_35',
#  'voice_all_start_end_time_day_36',
#  'voice_all_start_end_time_day_37',
#  'voice_all_start_end_time_day_38',
#  'voice_all_start_end_time_day_39',
#  'voice_all_start_end_time_day_40',
#  'voice_all_start_end_time_day_41',
#  'voice_all_start_end_time_day_42',
#  'voice_all_start_end_time_day_43',
#  'voice_all_start_end_time_day_44',
#  'voice_all_start_end_time_day_45',
#  'voice_all_start_end_time_day_1_rate',
#  'voice_all_start_end_time_day_2_rate',
#  'voice_all_start_end_time_day_3_rate',
#  'voice_all_start_end_time_day_4_rate',
#  'voice_all_start_end_time_day_5_rate',
#  'voice_all_start_end_time_day_6_rate',
#  'voice_all_start_end_time_day_7_rate',
#  'voice_all_start_end_time_day_8_rate',
#  'voice_all_start_end_time_day_9_rate',
#  'voice_all_start_end_time_day_10_rate',
#  'voice_all_start_end_time_day_11_rate',
#  'voice_all_start_end_time_day_12_rate',
#  'voice_all_start_end_time_day_13_rate',
#  'voice_all_start_end_time_day_14_rate',
#  'voice_all_start_end_time_day_15_rate',
#  'voice_all_start_end_time_day_16_rate',
#  'voice_all_start_end_time_day_17_rate',
#  'voice_all_start_end_time_day_18_rate',
#  'voice_all_start_end_time_day_19_rate',
#  'voice_all_start_end_time_day_20_rate',
#  'voice_all_start_end_time_day_21_rate',
#  'voice_all_start_end_time_day_22_rate',
#  'voice_all_start_end_time_day_23_rate',
#  'voice_all_start_end_time_day_24_rate',
#  'voice_all_start_end_time_day_25_rate',
#  'voice_all_start_end_time_day_26_rate',
#  'voice_all_start_end_time_day_27_rate',
#  'voice_all_start_end_time_day_28_rate',
#  'voice_all_start_end_time_day_29_rate',
#  'voice_all_start_end_time_day_30_rate',
#  'voice_all_start_end_time_day_31_rate',
#  'voice_all_start_end_time_day_32_rate',
#  'voice_all_start_end_time_day_33_rate',
#  'voice_all_start_end_time_day_34_rate',
#  'voice_all_start_end_time_day_35_rate',
#  'voice_all_start_end_time_day_36_rate',
#  'voice_all_start_end_time_day_37_rate',
#  'voice_all_start_end_time_day_38_rate',
#  'voice_all_start_end_time_day_39_rate',
#  'voice_all_start_end_time_day_40_rate',
#  'voice_all_start_end_time_day_41_rate',
#  'voice_all_start_end_time_day_42_rate',
#  'voice_all_start_end_time_day_43_rate',
#  'voice_all_start_end_time_day_44_rate',
#  'voice_all_start_end_time_day_45_rate',
#  'voice_all_start_time_hour_0',
#  'voice_all_start_time_hour_1',
#  'voice_all_start_time_hour_2',
#  'voice_all_start_time_hour_3',
#  'voice_all_start_time_hour_4',
#  'voice_all_start_time_hour_5',
#  'voice_all_start_time_hour_6',
#  'voice_all_start_time_hour_7',
#  'voice_all_start_time_hour_8',
#  'voice_all_start_time_hour_9',
#  'voice_all_start_time_hour_10',
#  'voice_all_start_time_hour_11',
#  'voice_all_start_time_hour_12',
#  'voice_all_start_time_hour_13',
#  'voice_all_start_time_hour_14',
#  'voice_all_start_time_hour_15',
#  'voice_all_start_time_hour_16',
#  'voice_all_start_time_hour_17',
#  'voice_all_start_time_hour_18',
#  'voice_all_start_time_hour_19',
#  'voice_all_start_time_hour_20',
#  'voice_all_start_time_hour_21',
#  'voice_all_start_time_hour_22',
#  'voice_all_start_time_hour_23',
#  'voice_all_start_time_hour_0_rate',
#  'voice_all_start_time_hour_1_rate',
#  'voice_all_start_time_hour_2_rate',
#  'voice_all_start_time_hour_3_rate',
#  'voice_all_start_time_hour_4_rate',
#  'voice_all_start_time_hour_5_rate',
#  'voice_all_start_time_hour_6_rate',
#  'voice_all_start_time_hour_7_rate',
#  'voice_all_start_time_hour_8_rate',
#  'voice_all_start_time_hour_9_rate',
#  'voice_all_start_time_hour_10_rate',
#  'voice_all_start_time_hour_11_rate',
#  'voice_all_start_time_hour_12_rate',
#  'voice_all_start_time_hour_13_rate',
#  'voice_all_start_time_hour_14_rate',
#  'voice_all_start_time_hour_15_rate',
#  'voice_all_start_time_hour_16_rate',
#  'voice_all_start_time_hour_17_rate',
#  'voice_all_start_time_hour_18_rate',
#  'voice_all_start_time_hour_19_rate',
#  'voice_all_start_time_hour_20_rate',
#  'voice_all_start_time_hour_21_rate',
#  'voice_all_start_time_hour_22_rate',
#  'voice_all_start_time_hour_23_rate',
#  'voice_all_end_time_hour_0',
#  'voice_all_end_time_hour_1',
#  'voice_all_end_time_hour_2',
#  'voice_all_end_time_hour_3',
#  'voice_all_end_time_hour_4',
#  'voice_all_end_time_hour_5',
#  'voice_all_end_time_hour_6',
#  'voice_all_end_time_hour_7',
#  'voice_all_end_time_hour_8',
#  'voice_all_end_time_hour_9',
#  'voice_all_end_time_hour_10',
#  'voice_all_end_time_hour_11',
#  'voice_all_end_time_hour_12',
#  'voice_all_end_time_hour_13',
#  'voice_all_end_time_hour_14',
#  'voice_all_end_time_hour_15',
#  'voice_all_end_time_hour_16',
#  'voice_all_end_time_hour_17',
#  'voice_all_end_time_hour_18',
#  'voice_all_end_time_hour_19',
#  'voice_all_end_time_hour_20',
#  'voice_all_end_time_hour_21',
#  'voice_all_end_time_hour_22',
#  'voice_all_end_time_hour_23',
#  'voice_all_end_time_hour_0_rate',
#  'voice_all_end_time_hour_1_rate',
#  'voice_all_end_time_hour_2_rate',
#  'voice_all_end_time_hour_3_rate',
#  'voice_all_end_time_hour_4_rate',
#  'voice_all_end_time_hour_5_rate',
#  'voice_all_end_time_hour_6_rate',
#  'voice_all_end_time_hour_7_rate',
#  'voice_all_end_time_hour_8_rate',
#  'voice_all_end_time_hour_9_rate',
#  'voice_all_end_time_hour_10_rate',
#  'voice_all_end_time_hour_11_rate',
#  'voice_all_end_time_hour_12_rate',
#  'voice_all_end_time_hour_13_rate',
#  'voice_all_end_time_hour_14_rate',
#  'voice_all_end_time_hour_15_rate',
#  'voice_all_end_time_hour_16_rate',
#  'voice_all_end_time_hour_17_rate',
#  'voice_all_end_time_hour_18_rate',
#  'voice_all_end_time_hour_19_rate',
#  'voice_all_end_time_hour_20_rate',
#  'voice_all_end_time_hour_21_rate',
#  'voice_all_end_time_hour_22_rate',
#  'voice_all_end_time_hour_23_rate',
#  'voice_all_start_time_minute_0',
#  'voice_all_start_time_minute_1',
#  'voice_all_start_time_minute_2',
#  'voice_all_start_time_minute_3',
#  'voice_all_start_time_minute_4',
#  'voice_all_start_time_minute_5',
#  'voice_all_start_time_minute_6',
#  'voice_all_start_time_minute_7',
#  'voice_all_start_time_minute_8',
#  'voice_all_start_time_minute_9',
#  'voice_all_start_time_minute_10',
#  'voice_all_start_time_minute_11',
#  'voice_all_start_time_minute_12',
#  'voice_all_start_time_minute_13',
#  'voice_all_start_time_minute_14',
#  'voice_all_start_time_minute_15',
#  'voice_all_start_time_minute_16',
#  'voice_all_start_time_minute_17',
#  'voice_all_start_time_minute_18',
#  'voice_all_start_time_minute_19',
#  'voice_all_start_time_minute_20',
#  'voice_all_start_time_minute_21',
#  'voice_all_start_time_minute_22',
#  'voice_all_start_time_minute_23',
#  'voice_all_start_time_minute_24',
#  'voice_all_start_time_minute_25',
#  'voice_all_start_time_minute_26',
#  'voice_all_start_time_minute_27',
#  'voice_all_start_time_minute_28',
#  'voice_all_start_time_minute_29',
#  'voice_all_start_time_minute_30',
#  'voice_all_start_time_minute_31',
#  'voice_all_start_time_minute_32',
#  'voice_all_start_time_minute_33',
#  'voice_all_start_time_minute_34',
#  'voice_all_start_time_minute_35',
#  'voice_all_start_time_minute_36',
#  'voice_all_start_time_minute_37',
#  'voice_all_start_time_minute_38',
#  'voice_all_start_time_minute_39',
#  'voice_all_start_time_minute_40',
#  'voice_all_start_time_minute_41',
#  'voice_all_start_time_minute_42',
#  'voice_all_start_time_minute_43',
#  'voice_all_start_time_minute_44',
#  'voice_all_start_time_minute_45',
#  'voice_all_start_time_minute_46',
#  'voice_all_start_time_minute_47',
#  'voice_all_start_time_minute_48',
#  'voice_all_start_time_minute_49',
#  'voice_all_start_time_minute_50',
#  'voice_all_start_time_minute_51',
#  'voice_all_start_time_minute_52',
#  'voice_all_start_time_minute_53',
#  'voice_all_start_time_minute_54',
#  'voice_all_start_time_minute_55',
#  'voice_all_start_time_minute_56',
#  'voice_all_start_time_minute_57',
#  'voice_all_start_time_minute_58',
#  'voice_all_start_time_minute_59',
#  'voice_all_start_time_minute_0_rate',
#  'voice_all_start_time_minute_1_rate',
#  'voice_all_start_time_minute_2_rate',
#  'voice_all_start_time_minute_3_rate',
#  'voice_all_start_time_minute_4_rate',
#  'voice_all_start_time_minute_5_rate',
#  'voice_all_start_time_minute_6_rate',
#  'voice_all_start_time_minute_7_rate',
#  'voice_all_start_time_minute_8_rate',
#  'voice_all_start_time_minute_9_rate',
#  'voice_all_start_time_minute_10_rate',
#  'voice_all_start_time_minute_11_rate',
#  'voice_all_start_time_minute_12_rate',
#  'voice_all_start_time_minute_13_rate',
#  'voice_all_start_time_minute_14_rate',
#  'voice_all_start_time_minute_15_rate',
#  'voice_all_start_time_minute_16_rate',
#  'voice_all_start_time_minute_17_rate',
#  'voice_all_start_time_minute_18_rate',
#  'voice_all_start_time_minute_19_rate',
#  'voice_all_start_time_minute_20_rate',
#  'voice_all_start_time_minute_21_rate',
#  'voice_all_start_time_minute_22_rate',
#  'voice_all_start_time_minute_23_rate',
#  'voice_all_start_time_minute_24_rate',
#  'voice_all_start_time_minute_25_rate',
#  'voice_all_start_time_minute_26_rate',
#  'voice_all_start_time_minute_27_rate',
#  'voice_all_start_time_minute_28_rate',
#  'voice_all_start_time_minute_29_rate',
#  'voice_all_start_time_minute_30_rate',
#  'voice_all_start_time_minute_31_rate',
#  'voice_all_start_time_minute_32_rate',
#  'voice_all_start_time_minute_33_rate',
#  'voice_all_start_time_minute_34_rate',
#  'voice_all_start_time_minute_35_rate',
#  'voice_all_start_time_minute_36_rate',
#  'voice_all_start_time_minute_37_rate',
#  'voice_all_start_time_minute_38_rate',
#  'voice_all_start_time_minute_39_rate',
#  'voice_all_start_time_minute_40_rate',
#  'voice_all_start_time_minute_41_rate',
#  'voice_all_start_time_minute_42_rate',
#  'voice_all_start_time_minute_43_rate',
#  'voice_all_start_time_minute_44_rate',
#  'voice_all_start_time_minute_45_rate',
#  'voice_all_start_time_minute_46_rate',
#  'voice_all_start_time_minute_47_rate',
#  'voice_all_start_time_minute_48_rate',
#  'voice_all_start_time_minute_49_rate',
#  'voice_all_start_time_minute_50_rate',
#  'voice_all_start_time_minute_51_rate',
#  'voice_all_start_time_minute_52_rate',
#  'voice_all_start_time_minute_53_rate',
#  'voice_all_start_time_minute_54_rate',
#  'voice_all_start_time_minute_55_rate',
#  'voice_all_start_time_minute_56_rate',
#  'voice_all_start_time_minute_57_rate',
#  'voice_all_start_time_minute_58_rate',
#  'voice_all_start_time_minute_59_rate',
#  'voice_all_end_time_minute_0',
#  'voice_all_end_time_minute_1',
#  'voice_all_end_time_minute_2',
#  'voice_all_end_time_minute_3',
#  'voice_all_end_time_minute_4',
#  'voice_all_end_time_minute_5',
#  'voice_all_end_time_minute_6',
#  'voice_all_end_time_minute_7',
#  'voice_all_end_time_minute_8',
#  'voice_all_end_time_minute_9',
#  'voice_all_end_time_minute_10',
#  'voice_all_end_time_minute_11',
#  'voice_all_end_time_minute_12',
#  'voice_all_end_time_minute_13',
#  'voice_all_end_time_minute_14',
#  'voice_all_end_time_minute_15',
#  'voice_all_end_time_minute_16',
#  'voice_all_end_time_minute_17',
#  'voice_all_end_time_minute_18',
#  'voice_all_end_time_minute_19',
#  'voice_all_end_time_minute_20',
#  'voice_all_end_time_minute_21',
#  'voice_all_end_time_minute_22',
#  'voice_all_end_time_minute_23',
#  'voice_all_end_time_minute_24',
#  'voice_all_end_time_minute_25',
#  'voice_all_end_time_minute_26',
#  'voice_all_end_time_minute_27',
#  'voice_all_end_time_minute_28',
#  'voice_all_end_time_minute_29',
#  'voice_all_end_time_minute_30',
#  'voice_all_end_time_minute_31',
#  'voice_all_end_time_minute_32',
#  'voice_all_end_time_minute_33',
#  'voice_all_end_time_minute_34',
#  'voice_all_end_time_minute_35',
#  'voice_all_end_time_minute_36',
#  'voice_all_end_time_minute_37',
#  'voice_all_end_time_minute_38',
#  'voice_all_end_time_minute_39',
#  'voice_all_end_time_minute_40',
#  'voice_all_end_time_minute_41',
#  'voice_all_end_time_minute_42',
#  'voice_all_end_time_minute_43',
#  'voice_all_end_time_minute_44',
#  'voice_all_end_time_minute_45',
#  'voice_all_end_time_minute_46',
#  'voice_all_end_time_minute_47',
#  'voice_all_end_time_minute_48',
#  'voice_all_end_time_minute_49',
#  'voice_all_end_time_minute_50',
#  'voice_all_end_time_minute_51',
#  'voice_all_end_time_minute_52',
#  'voice_all_end_time_minute_53',
#  'voice_all_end_time_minute_54',
#  'voice_all_end_time_minute_55',
#  'voice_all_end_time_minute_56',
#  'voice_all_end_time_minute_57',
#  'voice_all_end_time_minute_58',
#  'voice_all_end_time_minute_59',
#  'voice_all_end_time_minute_0_rate',
#  'voice_all_end_time_minute_1_rate',
#  'voice_all_end_time_minute_2_rate',
#  'voice_all_end_time_minute_3_rate',
#  'voice_all_end_time_minute_4_rate',
#  'voice_all_end_time_minute_5_rate',
#  'voice_all_end_time_minute_6_rate',
#  'voice_all_end_time_minute_7_rate',
#  'voice_all_end_time_minute_8_rate',
#  'voice_all_end_time_minute_9_rate',
#  'voice_all_end_time_minute_10_rate',
#  'voice_all_end_time_minute_11_rate',
#  'voice_all_end_time_minute_12_rate',
#  'voice_all_end_time_minute_13_rate',
#  'voice_all_end_time_minute_14_rate',
#  'voice_all_end_time_minute_15_rate',
#  'voice_all_end_time_minute_16_rate',
#  'voice_all_end_time_minute_17_rate',
#  'voice_all_end_time_minute_18_rate',
#  'voice_all_end_time_minute_19_rate',
#  'voice_all_end_time_minute_20_rate',
#  'voice_all_end_time_minute_21_rate',
#  'voice_all_end_time_minute_22_rate',
#  'voice_all_end_time_minute_23_rate',
#  'voice_all_end_time_minute_24_rate',
#  'voice_all_end_time_minute_25_rate',
#  'voice_all_end_time_minute_26_rate',
#  'voice_all_end_time_minute_27_rate',
#  'voice_all_end_time_minute_28_rate',
#  'voice_all_end_time_minute_29_rate',
#  'voice_all_end_time_minute_30_rate',
#  'voice_all_end_time_minute_31_rate',
#  'voice_all_end_time_minute_32_rate',
#  'voice_all_end_time_minute_33_rate',
#  'voice_all_end_time_minute_34_rate',
#  'voice_all_end_time_minute_35_rate',
#  'voice_all_end_time_minute_36_rate',
#  'voice_all_end_time_minute_37_rate',
#  'voice_all_end_time_minute_38_rate',
#  'voice_all_end_time_minute_39_rate',
#  'voice_all_end_time_minute_40_rate',
#  'voice_all_end_time_minute_41_rate',
#  'voice_all_end_time_minute_42_rate',
#  'voice_all_end_time_minute_43_rate',
#  'voice_all_end_time_minute_44_rate',
#  'voice_all_end_time_minute_45_rate',
#  'voice_all_end_time_minute_46_rate',
#  'voice_all_end_time_minute_47_rate',
#  'voice_all_end_time_minute_48_rate',
#  'voice_all_end_time_minute_49_rate',
#  'voice_all_end_time_minute_50_rate',
#  'voice_all_end_time_minute_51_rate',
#  'voice_all_end_time_minute_52_rate',
#  'voice_all_end_time_minute_53_rate',
#  'voice_all_end_time_minute_54_rate',
#  'voice_all_end_time_minute_55_rate',
#  'voice_all_end_time_minute_56_rate',
#  'voice_all_end_time_minute_57_rate',
#  'voice_all_end_time_minute_58_rate',
#  'voice_all_end_time_minute_59_rate',
#  'voice_all_start_time_second_0',
#  'voice_all_start_time_second_1',
#  'voice_all_start_time_second_2',
#  'voice_all_start_time_second_3',
#  'voice_all_start_time_second_4',
#  'voice_all_start_time_second_5',
#  'voice_all_start_time_second_6',
#  'voice_all_start_time_second_7',
#  'voice_all_start_time_second_8',
#  'voice_all_start_time_second_9',
#  'voice_all_start_time_second_10',
#  'voice_all_start_time_second_11',
#  'voice_all_start_time_second_12',
#  'voice_all_start_time_second_13',
#  'voice_all_start_time_second_14',
#  'voice_all_start_time_second_15',
#  'voice_all_start_time_second_16',
#  'voice_all_start_time_second_17',
#  'voice_all_start_time_second_18',
#  'voice_all_start_time_second_19',
#  'voice_all_start_time_second_20',
#  'voice_all_start_time_second_21',
#  'voice_all_start_time_second_22',
#  'voice_all_start_time_second_23',
#  'voice_all_start_time_second_24',
#  'voice_all_start_time_second_25',
#  'voice_all_start_time_second_26',
#  'voice_all_start_time_second_27',
#  'voice_all_start_time_second_28',
#  'voice_all_start_time_second_29',
#  'voice_all_start_time_second_30',
#  'voice_all_start_time_second_31',
#  'voice_all_start_time_second_32',
#  'voice_all_start_time_second_33',
#  'voice_all_start_time_second_34',
#  'voice_all_start_time_second_35',
#  'voice_all_start_time_second_36',
#  'voice_all_start_time_second_37',
#  'voice_all_start_time_second_38',
#  'voice_all_start_time_second_39',
#  'voice_all_start_time_second_40',
#  'voice_all_start_time_second_41',
#  'voice_all_start_time_second_42',
#  'voice_all_start_time_second_43',
#  'voice_all_start_time_second_44',
#  'voice_all_start_time_second_45',
#  'voice_all_start_time_second_46',
#  'voice_all_start_time_second_47',
#  'voice_all_start_time_second_48',
#  'voice_all_start_time_second_49',
#  'voice_all_start_time_second_50',
#  'voice_all_start_time_second_51',
#  'voice_all_start_time_second_52',
#  'voice_all_start_time_second_53',
#  'voice_all_start_time_second_54',
#  'voice_all_start_time_second_55',
#  'voice_all_start_time_second_56',
#  'voice_all_start_time_second_57',
#  'voice_all_start_time_second_58',
#  'voice_all_start_time_second_59',
#  'voice_all_start_time_second_0_rate',
#  'voice_all_start_time_second_1_rate',
#  'voice_all_start_time_second_2_rate',
#  'voice_all_start_time_second_3_rate',
#  'voice_all_start_time_second_4_rate',
#  'voice_all_start_time_second_5_rate',
#  'voice_all_start_time_second_6_rate',
#  'voice_all_start_time_second_7_rate',
#  'voice_all_start_time_second_8_rate',
#  'voice_all_start_time_second_9_rate',
#  'voice_all_start_time_second_10_rate',
#  'voice_all_start_time_second_11_rate',
#  'voice_all_start_time_second_12_rate',
#  'voice_all_start_time_second_13_rate',
#  'voice_all_start_time_second_14_rate',
#  'voice_all_start_time_second_15_rate',
#  'voice_all_start_time_second_16_rate',
#  'voice_all_start_time_second_17_rate',
#  'voice_all_start_time_second_18_rate',
#  'voice_all_start_time_second_19_rate',
#  'voice_all_start_time_second_20_rate',
#  'voice_all_start_time_second_21_rate',
#  'voice_all_start_time_second_22_rate',
#  'voice_all_start_time_second_23_rate',
#  'voice_all_start_time_second_24_rate',
#  'voice_all_start_time_second_25_rate',
#  'voice_all_start_time_second_26_rate',
#  'voice_all_start_time_second_27_rate',
#  'voice_all_start_time_second_28_rate',
#  'voice_all_start_time_second_29_rate',
#  'voice_all_start_time_second_30_rate',
#  'voice_all_start_time_second_31_rate',
#  'voice_all_start_time_second_32_rate',
#  'voice_all_start_time_second_33_rate',
#  'voice_all_start_time_second_34_rate',
#  'voice_all_start_time_second_35_rate',
#  'voice_all_start_time_second_36_rate',
#  'voice_all_start_time_second_37_rate',
#  'voice_all_start_time_second_38_rate',
#  'voice_all_start_time_second_39_rate',
#  'voice_all_start_time_second_40_rate',
#  'voice_all_start_time_second_41_rate',
#  'voice_all_start_time_second_42_rate',
#  'voice_all_start_time_second_43_rate',
#  'voice_all_start_time_second_44_rate',
#  'voice_all_start_time_second_45_rate',
#  'voice_all_start_time_second_46_rate',
#  'voice_all_start_time_second_47_rate',
#  'voice_all_start_time_second_48_rate',
#  'voice_all_start_time_second_49_rate',
#  'voice_all_start_time_second_50_rate',
#  'voice_all_start_time_second_51_rate',
#  'voice_all_start_time_second_52_rate',
#  'voice_all_start_time_second_53_rate',
#  'voice_all_start_time_second_54_rate',
#  'voice_all_start_time_second_55_rate',
#  'voice_all_start_time_second_56_rate',
#  'voice_all_start_time_second_57_rate',
#  'voice_all_start_time_second_58_rate',
#  'voice_all_start_time_second_59_rate',
#  'voice_all_end_time_second_0',
#  'voice_all_end_time_second_1',
#  'voice_all_end_time_second_2',
#  'voice_all_end_time_second_3',
#  'voice_all_end_time_second_4',
#  'voice_all_end_time_second_5',
#  'voice_all_end_time_second_6',
#  'voice_all_end_time_second_7',
#  'voice_all_end_time_second_8',
#  'voice_all_end_time_second_9',
#  'voice_all_end_time_second_10',
#  'voice_all_end_time_second_11',
#  'voice_all_end_time_second_12',
#  'voice_all_end_time_second_13',
#  'voice_all_end_time_second_14',
#  'voice_all_end_time_second_15',
#  'voice_all_end_time_second_16',
#  'voice_all_end_time_second_17',
#  'voice_all_end_time_second_18',
#  'voice_all_end_time_second_19',
#  'voice_all_end_time_second_20',
#  'voice_all_end_time_second_21',
#  'voice_all_end_time_second_22',
#  'voice_all_end_time_second_23',
#  'voice_all_end_time_second_24',
#  'voice_all_end_time_second_25',
#  'voice_all_end_time_second_26',
#  'voice_all_end_time_second_27',
#  'voice_all_end_time_second_28',
#  'voice_all_end_time_second_29',
#  'voice_all_end_time_second_30',
#  'voice_all_end_time_second_31',
#  'voice_all_end_time_second_32',
#  'voice_all_end_time_second_33',
#  'voice_all_end_time_second_34',
#  'voice_all_end_time_second_35',
#  'voice_all_end_time_second_36',
#  'voice_all_end_time_second_37',
#  'voice_all_end_time_second_38',
#  'voice_all_end_time_second_39',
#  'voice_all_end_time_second_40',
#  'voice_all_end_time_second_41',
#  'voice_all_end_time_second_42',
#  'voice_all_end_time_second_43',
#  'voice_all_end_time_second_44',
#  'voice_all_end_time_second_45',
#  'voice_all_end_time_second_46',
#  'voice_all_end_time_second_47',
#  'voice_all_end_time_second_48',
#  'voice_all_end_time_second_49',
#  'voice_all_end_time_second_50',
#  'voice_all_end_time_second_51',
#  'voice_all_end_time_second_52',
#  'voice_all_end_time_second_53',
#  'voice_all_end_time_second_54',
#  'voice_all_end_time_second_55',
#  'voice_all_end_time_second_56',
#  'voice_all_end_time_second_57',
#  'voice_all_end_time_second_58',
#  'voice_all_end_time_second_59',
#  'voice_all_end_time_second_0_rate',
#  'voice_all_end_time_second_1_rate',
#  'voice_all_end_time_second_2_rate',
#  'voice_all_end_time_second_3_rate',
#  'voice_all_end_time_second_4_rate',
#  'voice_all_end_time_second_5_rate',
#  'voice_all_end_time_second_6_rate',
#  'voice_all_end_time_second_7_rate',
#  'voice_all_end_time_second_8_rate',
#  'voice_all_end_time_second_9_rate',
#  'voice_all_end_time_second_10_rate',
#  'voice_all_end_time_second_11_rate',
#  'voice_all_end_time_second_12_rate',
#  'voice_all_end_time_second_13_rate',
#  'voice_all_end_time_second_14_rate',
#  'voice_all_end_time_second_15_rate',
#  'voice_all_end_time_second_16_rate',
#  'voice_all_end_time_second_17_rate',
#  'voice_all_end_time_second_18_rate',
#  'voice_all_end_time_second_19_rate',
#  'voice_all_end_time_second_20_rate',
#  'voice_all_end_time_second_21_rate',
#  'voice_all_end_time_second_22_rate',
#  'voice_all_end_time_second_23_rate',
#  'voice_all_end_time_second_24_rate',
#  'voice_all_end_time_second_25_rate',
#  'voice_all_end_time_second_26_rate',
#  'voice_all_end_time_second_27_rate',
#  'voice_all_end_time_second_28_rate',
#  'voice_all_end_time_second_29_rate',
#  'voice_all_end_time_second_30_rate',
#  'voice_all_end_time_second_31_rate',
#  'voice_all_end_time_second_32_rate',
#  'voice_all_end_time_second_33_rate',
#  'voice_all_end_time_second_34_rate',
#  'voice_all_end_time_second_35_rate',
#  'voice_all_end_time_second_36_rate',
#  'voice_all_end_time_second_37_rate',
#  'voice_all_end_time_second_38_rate',
#  'voice_all_end_time_second_39_rate',
#  'voice_all_end_time_second_40_rate',
#  'voice_all_end_time_second_41_rate',
#  'voice_all_end_time_second_42_rate',
#  'voice_all_end_time_second_43_rate',
#  'voice_all_end_time_second_44_rate',
#  'voice_all_end_time_second_45_rate',
#  'voice_all_end_time_second_46_rate',
#  'voice_all_end_time_second_47_rate',
#  'voice_all_end_time_second_48_rate',
#  'voice_all_end_time_second_49_rate',
#  'voice_all_end_time_second_50_rate',
#  'voice_all_end_time_second_51_rate',
#  'voice_all_end_time_second_52_rate',
#  'voice_all_end_time_second_53_rate',
#  'voice_all_end_time_second_54_rate',
#  'voice_all_end_time_second_55_rate',
#  'voice_all_end_time_second_56_rate',
#  'voice_all_end_time_second_57_rate',
#  'voice_all_end_time_second_58_rate',
#  'voice_all_end_time_second_59_rate',
#  'voice_all_diff_time_sum',
#  'voice_all_diff_time_avg',
#  'voice_all_diff_time_max',
#  'voice_all_diff_time_min',
#  'voice_all_diff_time_std',
#  'voice_all_diff_time_skew',
#  'voice_all_diff_time_jc',
#  'voice_all_diff_time_fd',
#  'voice_all_start_time_last',
#  'voice_all_start_time_first',
#  'voice_all_end_time_last',
#  'voice_all_end_time_first',
#  'voice_all_start_time_last_start_time_first_diff',
#  'voice_all_end_time_last_end_time_first_diff',
#  'voice_all_end_time_first_start_time_first_diff',
#  'voice_all_end_time_last_start_time_last_diff',
#  'voice_all_end_time_first_start_time_first_diff_rate',
#  'voice_all_end_time_last_start_time_last_diff_rate',
#  'voice_all_start_time_sum',
#  'voice_all_start_time_avg',
#  'voice_all_start_time_max',
#  'voice_all_start_time_min',
#  'voice_all_start_time_std',
#  'voice_all_start_time_skew',
#  'voice_all_start_time_jc',
#  'voice_all_start_time_fd',
#  'voice_all_end_time_sum',
#  'voice_all_end_time_avg',
#  'voice_all_end_time_max',
#  'voice_all_end_time_min',
#  'voice_all_end_time_std',
#  'voice_all_end_time_skew',
#  'voice_all_end_time_jc',
#  'voice_all_end_time_fd',
#  'sms_all_cnt',
#  'sms_all_unique_cnt',
#  'sms_all_per_opp_rate',
#  'sms_all_opp_head_unique_cnt',
#  'sms_all_opp_head_little_head',
#  'sms_all_opp_head_many_head',
#  'sms_all_opp_head_many_head_cnt',
#  'sms_all_opp_head_many_head_cnt_rate',
#  'sms_all_opp_head_many_head_cnt_rate_unique',
#  'sms_all_opp_len_5',
#  'sms_all_opp_len_7',
#  'sms_all_opp_len_8',
#  'sms_all_opp_len_9',
#  'sms_all_opp_len_10',
#  'sms_all_opp_len_11',
#  'sms_all_opp_len_12',
#  'sms_all_opp_len_13',
#  'sms_all_opp_len_14',
#  'sms_all_opp_len_15',
#  'sms_all_opp_len_16',
#  'sms_all_opp_len_17',
#  'sms_all_opp_len_19',
#  'sms_all_opp_len_20',
#  'sms_all_opp_len_11_rate',
#  'sms_all_opp_len_little_head',
#  'sms_all_opp_len_many_head',
#  'sms_all_in_out_0',
#  'sms_all_in_out_1',
#  'sms_all_in_out_0_rate',
#  'sms_all_in_out_1_rate',
#  'sms_all_start_time_day_1',
#  'sms_all_start_time_day_2',
#  'sms_all_start_time_day_3',
#  'sms_all_start_time_day_4',
#  'sms_all_start_time_day_5',
#  'sms_all_start_time_day_6',
#  'sms_all_start_time_day_7',
#  'sms_all_start_time_day_8',
#  'sms_all_start_time_day_9',
#  'sms_all_start_time_day_10',
#  'sms_all_start_time_day_11',
#  'sms_all_start_time_day_12',
#  'sms_all_start_time_day_13',
#  'sms_all_start_time_day_14',
#  'sms_all_start_time_day_15',
#  'sms_all_start_time_day_16',
#  'sms_all_start_time_day_17',
#  'sms_all_start_time_day_18',
#  'sms_all_start_time_day_19',
#  'sms_all_start_time_day_20',
#  'sms_all_start_time_day_21',
#  'sms_all_start_time_day_22',
#  'sms_all_start_time_day_23',
#  'sms_all_start_time_day_24',
#  'sms_all_start_time_day_25',
#  'sms_all_start_time_day_26',
#  'sms_all_start_time_day_27',
#  'sms_all_start_time_day_28',
#  'sms_all_start_time_day_29',
#  'sms_all_start_time_day_30',
#  'sms_all_start_time_day_31',
#  'sms_all_start_time_day_32',
#  'sms_all_start_time_day_33',
#  'sms_all_start_time_day_34',
#  'sms_all_start_time_day_35',
#  'sms_all_start_time_day_36',
#  'sms_all_start_time_day_37',
#  'sms_all_start_time_day_38',
#  'sms_all_start_time_day_39',
#  'sms_all_start_time_day_40',
#  'sms_all_start_time_day_41',
#  'sms_all_start_time_day_42',
#  'sms_all_start_time_day_43',
#  'sms_all_start_time_day_44',
#  'sms_all_start_time_day_45',
#  'sms_all_start_time_day_1_rate',
#  'sms_all_start_time_day_2_rate',
#  'sms_all_start_time_day_3_rate',
#  'sms_all_start_time_day_4_rate',
#  'sms_all_start_time_day_5_rate',
#  'sms_all_start_time_day_6_rate',
#  'sms_all_start_time_day_7_rate',
#  'sms_all_start_time_day_8_rate',
#  'sms_all_start_time_day_9_rate',
#  'sms_all_start_time_day_10_rate',
#  'sms_all_start_time_day_11_rate',
#  'sms_all_start_time_day_12_rate',
#  'sms_all_start_time_day_13_rate',
#  'sms_all_start_time_day_14_rate',
#  'sms_all_start_time_day_15_rate',
#  'sms_all_start_time_day_16_rate',
#  'sms_all_start_time_day_17_rate',
#  'sms_all_start_time_day_18_rate',
#  'sms_all_start_time_day_19_rate',
#  'sms_all_start_time_day_20_rate',
#  'sms_all_start_time_day_21_rate',
#  'sms_all_start_time_day_22_rate',
#  'sms_all_start_time_day_23_rate',
#  'sms_all_start_time_day_24_rate',
#  'sms_all_start_time_day_25_rate',
#  'sms_all_start_time_day_26_rate',
#  'sms_all_start_time_day_27_rate',
#  'sms_all_start_time_day_28_rate',
#  'sms_all_start_time_day_29_rate',
#  'sms_all_start_time_day_30_rate',
#  'sms_all_start_time_day_31_rate',
#  'sms_all_start_time_day_32_rate',
#  'sms_all_start_time_day_33_rate',
#  'sms_all_start_time_day_34_rate',
#  'sms_all_start_time_day_35_rate',
#  'sms_all_start_time_day_36_rate',
#  'sms_all_start_time_day_37_rate',
#  'sms_all_start_time_day_38_rate',
#  'sms_all_start_time_day_39_rate',
#  'sms_all_start_time_day_40_rate',
#  'sms_all_start_time_day_41_rate',
#  'sms_all_start_time_day_42_rate',
#  'sms_all_start_time_day_43_rate',
#  'sms_all_start_time_day_44_rate',
#  'sms_all_start_time_day_45_rate',
#  'sms_all_start_time_hour_0',
#  'sms_all_start_time_hour_1',
#  'sms_all_start_time_hour_2',
#  'sms_all_start_time_hour_3',
#  'sms_all_start_time_hour_4',
#  'sms_all_start_time_hour_5',
#  'sms_all_start_time_hour_6',
#  'sms_all_start_time_hour_7',
#  'sms_all_start_time_hour_8',
#  'sms_all_start_time_hour_9',
#  'sms_all_start_time_hour_10',
#  'sms_all_start_time_hour_11',
#  'sms_all_start_time_hour_12',
#  'sms_all_start_time_hour_13',
#  'sms_all_start_time_hour_14',
#  'sms_all_start_time_hour_15',
#  'sms_all_start_time_hour_16',
#  'sms_all_start_time_hour_17',
#  'sms_all_start_time_hour_18',
#  'sms_all_start_time_hour_19',
#  'sms_all_start_time_hour_20',
#  'sms_all_start_time_hour_21',
#  'sms_all_start_time_hour_22',
#  'sms_all_start_time_hour_23',
#  'sms_all_start_time_hour_0_rate',
#  'sms_all_start_time_hour_1_rate',
#  'sms_all_start_time_hour_2_rate',
#  'sms_all_start_time_hour_3_rate',
#  'sms_all_start_time_hour_4_rate',
#  'sms_all_start_time_hour_5_rate',
#  'sms_all_start_time_hour_6_rate',
#  'sms_all_start_time_hour_7_rate',
#  'sms_all_start_time_hour_8_rate',
#  'sms_all_start_time_hour_9_rate',
#  'sms_all_start_time_hour_10_rate',
#  'sms_all_start_time_hour_11_rate',
#  'sms_all_start_time_hour_12_rate',
#  'sms_all_start_time_hour_13_rate',
#  'sms_all_start_time_hour_14_rate',
#  'sms_all_start_time_hour_15_rate',
#  'sms_all_start_time_hour_16_rate',
#  'sms_all_start_time_hour_17_rate',
#  'sms_all_start_time_hour_18_rate',
#  'sms_all_start_time_hour_19_rate',
#  'sms_all_start_time_hour_20_rate',
#  'sms_all_start_time_hour_21_rate',
#  'sms_all_start_time_hour_22_rate',
#  'sms_all_start_time_hour_23_rate',
#  'sms_all_start_time_minute_0',
#  'sms_all_start_time_minute_1',
#  'sms_all_start_time_minute_2',
#  'sms_all_start_time_minute_3',
#  'sms_all_start_time_minute_4',
#  'sms_all_start_time_minute_5',
#  'sms_all_start_time_minute_6',
#  'sms_all_start_time_minute_7',
#  'sms_all_start_time_minute_8',
#  'sms_all_start_time_minute_9',
#  'sms_all_start_time_minute_10',
#  'sms_all_start_time_minute_11',
#  'sms_all_start_time_minute_12',
#  'sms_all_start_time_minute_13',
#  'sms_all_start_time_minute_14',
#  'sms_all_start_time_minute_15',
#  'sms_all_start_time_minute_16',
#  'sms_all_start_time_minute_17',
#  'sms_all_start_time_minute_18',
#  'sms_all_start_time_minute_19',
#  'sms_all_start_time_minute_20',
#  'sms_all_start_time_minute_21',
#  'sms_all_start_time_minute_22',
#  'sms_all_start_time_minute_23',
#  'sms_all_start_time_minute_24',
#  'sms_all_start_time_minute_25',
#  'sms_all_start_time_minute_26',
#  'sms_all_start_time_minute_27',
#  'sms_all_start_time_minute_28',
#  'sms_all_start_time_minute_29',
#  'sms_all_start_time_minute_30',
#  'sms_all_start_time_minute_31',
#  'sms_all_start_time_minute_32',
#  'sms_all_start_time_minute_33',
#  'sms_all_start_time_minute_34',
#  'sms_all_start_time_minute_35',
#  'sms_all_start_time_minute_36',
#  'sms_all_start_time_minute_37',
#  'sms_all_start_time_minute_38',
#  'sms_all_start_time_minute_39',
#  'sms_all_start_time_minute_40',
#  'sms_all_start_time_minute_41',
#  'sms_all_start_time_minute_42',
#  'sms_all_start_time_minute_43',
#  'sms_all_start_time_minute_44',
#  'sms_all_start_time_minute_45',
#  'sms_all_start_time_minute_46',
#  'sms_all_start_time_minute_47',
#  'sms_all_start_time_minute_48',
#  'sms_all_start_time_minute_49',
#  'sms_all_start_time_minute_50',
#  'sms_all_start_time_minute_51',
#  'sms_all_start_time_minute_52',
#  'sms_all_start_time_minute_53',
#  'sms_all_start_time_minute_54',
#  'sms_all_start_time_minute_55',
#  'sms_all_start_time_minute_56',
#  'sms_all_start_time_minute_57',
#  'sms_all_start_time_minute_58',
#  'sms_all_start_time_minute_59',
#  'sms_all_start_time_minute_0_rate',
#  'sms_all_start_time_minute_1_rate',
#  'sms_all_start_time_minute_2_rate',
#  'sms_all_start_time_minute_3_rate',
#  'sms_all_start_time_minute_4_rate',
#  'sms_all_start_time_minute_5_rate',
#  'sms_all_start_time_minute_6_rate',
#  'sms_all_start_time_minute_7_rate',
#  'sms_all_start_time_minute_8_rate',
#  'sms_all_start_time_minute_9_rate',
#  'sms_all_start_time_minute_10_rate',
#  'sms_all_start_time_minute_11_rate',
#  'sms_all_start_time_minute_12_rate',
#  'sms_all_start_time_minute_13_rate',
#  'sms_all_start_time_minute_14_rate',
#  'sms_all_start_time_minute_15_rate',
#  'sms_all_start_time_minute_16_rate',
#  'sms_all_start_time_minute_17_rate',
#  'sms_all_start_time_minute_18_rate',
#  'sms_all_start_time_minute_19_rate',
#  'sms_all_start_time_minute_20_rate',
#  'sms_all_start_time_minute_21_rate',
#  'sms_all_start_time_minute_22_rate',
#  'sms_all_start_time_minute_23_rate',
#  'sms_all_start_time_minute_24_rate',
#  'sms_all_start_time_minute_25_rate',
#  'sms_all_start_time_minute_26_rate',
#  'sms_all_start_time_minute_27_rate',
#  'sms_all_start_time_minute_28_rate',
#  'sms_all_start_time_minute_29_rate',
#  'sms_all_start_time_minute_30_rate',
#  'sms_all_start_time_minute_31_rate',
#  ...]

# %%
output = open('xfeatures906.txt','w')

for feat,k in importance:
    output.write("%s\n" % feat)

output.close()

# %%
used_feat = [feat for feat,k in importance]
no_userd_feat = set(features) - set(used_feat)

output = open('no_xfeatures906.txt','w')
for feat in no_userd_feat:
    output.write("%s\n" % feat)

output.close()
